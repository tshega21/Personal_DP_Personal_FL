# %%
import os
import sys

paths = [
    "/Volumes/Users/shegao_t1/DP_Research/Personal_DP_Personal_FL/rpdp_fl",
    "/Volumes/Users/shegao_t1/DP_Research/Personal_DP_Personal_FL/rpdp_fl/myopacus",
    "/Volumes/Users/shegao_t1/DP_Research/Personal_DP_Personal_FL/rpdp_fl/torchdp",
    "/your/path/rpdp_fl/experiments",
]

for p in paths:
    if p not in sys.path:
        sys.path.append(p)

# Optional: also update environment variable
os.environ["PYTHONPATH"] = ":".join(sys.path)

# %%
from myopacus.accountants.rpdp_utils import GENERATE_EPSILONS_FUNC
import numpy as np
import pandas as pd

all_results = []
#results_dir = "./original_submission_results/fed_heart_disease/"
#all_results.append(pd.read_csv(os.path.join(results_dir, "results_heart_disease.csv")))
results_dir = "./original_submission_results/fed_mnist_iid"
all_results.append(pd.read_csv(os.path.join(results_dir, "results_mnist.csv")))
all_results.append(pd.read_csv(os.path.join(results_dir, "results_dittoglobal_mnist.csv")))
all_results.append(pd.read_csv(os.path.join(results_dir, "results_dittopersonal_mnist.csv")))


#results_dir = "./original_submission_results/fed_mnist_niid"
#all_results.append(pd.read_csv(os.path.join(results_dir, "results_mnist.csv")))

print(all_results)

#all_results.append(pd.read_csv(os.path.join(results_dir, "results_dittoglobal_mnist.csv")))


SETTINGS = {
    "ThreeLevels": [[[0.7,0.2,0.1], [0.1, 1.0, 5.0]]],
    "BoundedPareto": [[4, 0.1]], 
    "BoundedMixGauss": [[[0.7,0.2,0.1], [(0.1, 0.05), (1.0, 0.1), (5.0, 0.5)]]],
}
MIN_EPSILON, MAX_EPSILON = 0.1, 10.0
BoundedFunc = lambda values: np.array([min(max(x, MIN_EPSILON), MAX_EPSILON) for x in values])

enames = ["ThreeLevels", "BoundedMixGauss", "BoundedPareto"]
methods = ['PrivacyFree', 'Ours', 'Dropout', 'StrongForAll']
datasets = ['FedAvg','Ditto-Global', 'Ditto-Personal']
#datasets = ['Fed-Heart-Disease', 'MNIST-IID', 'MNIST-NonIID']

linestyle_str = [
    ("solid", "solid"),  # Same as (0, ()) or '-'
    ("dotted", "dotted"),  # Same as (0, (1, 1)) or ':'
    ("dashed", "dashed"),  # Same as '--'
    ("dashdot", "dashdot"),
]
linestyle_tuple = [
    ("loosely dotted", (0, (1, 10))),
    ("densely dotted", (0, (1, 1))),
    ("loosely dashed", (0, (5, 10))),
    ("densely dashed", (0, (5, 1))),
    ("loosely dashdotted", (0, (3, 10, 1, 10))),
    ("densely dashdotted", (0, (3, 1, 1, 1))),
    ("dashdotdotted", (0, (3, 5, 1, 5, 1, 5))),
    ("loosely dashdotdotted", (0, (3, 10, 1, 10, 1, 10))),
    ("densely dashdotdotted", (0, (3, 1, 1, 1, 1, 1))),
]
linestyles = linestyle_tuple + linestyle_str
legend_font = {'style': 'normal', 'size': 8, 'weight': "normal"}
label_font = {'family':'sans-serif', 'size': 10.5, 'weight': "normal"}
title_font = {'family':'sans-serif', 'size': 10.5, 'weight': "bold"}
# Out:
# [                                                 perf  mean_perf  \
# 0   [0.3463, 0.9531, 0.9719, 0.9753, 0.9789, 0.980...     0.9845
# 1   [0.1899, 0.2321, 0.2999, 0.5376, 0.6058, 0.639...     0.8205
# 2   [0.1411, 0.1634, 0.1975, 0.1876, 0.2507, 0.377...     0.6004
# 3   [0.1066, 0.1819, 0.1758, 0.3534, 0.4424, 0.514...     0.7577
# 4   [0.2014, 0.1258, 0.2657, 0.3682, 0.4709, 0.506...     0.8140
# 5   [0.1411, 0.1634, 0.1975, 0.1876, 0.2507, 0.377...     0.6004
# 6   [0.1629, 0.2355, 0.2135, 0.3152, 0.3317, 0.434...     0.7009
# 7   [0.1423, 0.2047, 0.299, 0.59, 0.6161, 0.6412, ...     0.8204
# 8   [0.1411, 0.1634, 0.1975, 0.1876, 0.2507, 0.377...     0.6004
# 9   [0.1356, 0.2254, 0.2069, 0.3175, 0.4567, 0.520...     0.7524
# 10  [0.4981, 0.9624, 0.9706, 0.9765, 0.9769, 0.974...     0.9854
# 11  [0.1014, 0.1566, 0.3784, 0.6002, 0.6386, 0.681...     0.8511
# 12  [0.0862, 0.125, 0.2147, 0.2985, 0.3095, 0.429,...     0.5973
# 13  [0.0997, 0.2156, 0.315, 0.4916, 0.5673, 0.5384...     0.7562
# 14  [0.1725, 0.2868, 0.4177, 0.5283, 0.6033, 0.632...     0.8327
# 15  [0.0862, 0.125, 0.2147, 0.2985, 0.3095, 0.429,...     0.5973
# 16  [0.1013, 0.2435, 0.3703, 0.3804, 0.4677, 0.499...     0.7416
# 17  [0.1107, 0.1562, 0.3747, 0.5689, 0.6559, 0.687...     0.8534
# 18  [0.0862, 0.125, 0.2147, 0.2985, 0.3095, 0.429,...     0.5973
# 19  [0.0995, 0.2186, 0.2667, 0.4183, 0.5784, 0.543...     0.7520
# 20  [0.4596, 0.9562, 0.9675, 0.9746, 0.9737, 0.979...     0.9847
# 21  [0.1737, 0.3339, 0.4074, 0.5633, 0.6067, 0.705...     0.8500
# 22  [0.1476, 0.0997, 0.156, 0.2604, 0.2453, 0.3702...     0.6553
# 23  [0.1218, 0.2548, 0.2754, 0.355, 0.4974, 0.598,...     0.8206
# 24  [0.1769, 0.3005, 0.4291, 0.4731, 0.5956, 0.637...     0.8332
# 25  [0.1476, 0.0997, 0.156, 0.2604, 0.2453, 0.3702...     0.6553
# 26  [0.1919, 0.1543, 0.3286, 0.4461, 0.446, 0.5213...     0.7349
# 27  [0.1499, 0.2546, 0.4155, 0.5419, 0.6098, 0.687...     0.8457
# 28  [0.1476, 0.0997, 0.156, 0.2604, 0.2453, 0.3702...     0.6553
# 29  [0.1641, 0.2802, 0.2763, 0.3572, 0.4866, 0.588...     0.8178
# 30  [0.3867, 0.9582, 0.9702, 0.9764, 0.9775, 0.976...     0.9857
# 31  [0.1622, 0.2425, 0.3651, 0.5003, 0.5602, 0.609...     0.8133
# 32  [0.1222, 0.1673, 0.2466, 0.2476, 0.4167, 0.418...     0.6188
# 33  [0.1418, 0.1569, 0.2735, 0.416, 0.4911, 0.5649...     0.7483
# 34  [0.1134, 0.1098, 0.3969, 0.4961, 0.5745, 0.621...     0.8059
# 35  [0.1222, 0.1673, 0.2466, 0.2476, 0.4167, 0.418...     0.6188
# 36  [0.1577, 0.2409, 0.2626, 0.4531, 0.5234, 0.532...     0.7378
# 37  [0.1896, 0.2235, 0.3534, 0.4506, 0.5617, 0.604...     0.8111
# 38  [0.1222, 0.1673, 0.2466, 0.2476, 0.4167, 0.418...     0.6188
# 39  [0.134, 0.1421, 0.2868, 0.4007, 0.5158, 0.546,...     0.7635
# 40  [0.2923, 0.9525, 0.9666, 0.9756, 0.979, 0.9809...     0.9841
# 41  [0.1193, 0.1514, 0.3102, 0.4339, 0.5199, 0.638...     0.8301
# 42  [0.1147, 0.2052, 0.1781, 0.27, 0.2702, 0.3442,...     0.5557
# 43  [0.1506, 0.1664, 0.2466, 0.2625, 0.4337, 0.518...     0.7238
# 44  [0.1477, 0.1912, 0.3589, 0.4023, 0.4877, 0.601...     0.8118
# 45  [0.1147, 0.2052, 0.1781, 0.27, 0.2702, 0.3442,...     0.5557
# 46  [0.1009, 0.1834, 0.2826, 0.2901, 0.4205, 0.506...     0.7400
# 47  [0.1229, 0.1519, 0.3231, 0.4318, 0.5197, 0.604...     0.8289
# 48  [0.1147, 0.2052, 0.1781, 0.27, 0.2702, 0.3442,...     0.5557
# 49  [0.1561, 0.1764, 0.2227, 0.2903, 0.4557, 0.512...     0.7161
#
#                                  e      d     nm  norm   bs  seed
# 0                      PrivacyFree    NaN    NaN   NaN  128    42
# 1               ThreeLevels-0-Ours  0.001   9.74   1.0  435    42
# 2       ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    42
# 3            ThreeLevels-0-Dropout  0.001   9.74   1.0  175    42
# 4             BoundedPareto-0-Ours  0.001   9.74   1.0  293    42
# 5     BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    42
# 6          BoundedPareto-0-Dropout  0.001   9.74   1.0  120    42
# 7           BoundedMixGauss-0-Ours  0.001   9.74   1.0  411    42
# 8   BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    42
# 9        BoundedMixGauss-0-Dropout  0.001   9.74   1.0  166    42
# 10                     PrivacyFree    NaN    NaN   NaN  128    43
# 11              ThreeLevels-0-Ours  0.001   9.74   1.0  435    43
# 12      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    43
# 13           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    43
# 14            BoundedPareto-0-Ours  0.001   9.74   1.0  299    43
# 15    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    43
# 16         BoundedPareto-0-Dropout  0.001   9.74   1.0  123    43
# 17          BoundedMixGauss-0-Ours  0.001   9.74   1.0  471    43
# 18  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    43
# 19       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  185    43
# 20                     PrivacyFree    NaN    NaN   NaN  128    44
# 21              ThreeLevels-0-Ours  0.001   9.74   1.0  435    44
# 22      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    44
# 23           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    44
# 24            BoundedPareto-0-Ours  0.001   9.74   1.0  295    44
# 25    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    44
# 26         BoundedPareto-0-Dropout  0.001   9.74   1.0  123    44
# 27          BoundedMixGauss-0-Ours  0.001   9.74   1.0  442    44
# 28  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    44
# 29       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  175    44
# 30                     PrivacyFree    NaN    NaN   NaN  128    45
# 31              ThreeLevels-0-Ours  0.001   9.74   1.0  435    45
# 32      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    45
# 33           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    45
# 34            BoundedPareto-0-Ours  0.001   9.74   1.0  289    45
# 35    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    45
# 36         BoundedPareto-0-Dropout  0.001   9.74   1.0  118    45
# 37          BoundedMixGauss-0-Ours  0.001   9.74   1.0  447    45
# 38  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    45
# 39       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  180    45
# 40                     PrivacyFree    NaN    NaN   NaN  128    46
# 41              ThreeLevels-0-Ours  0.001   9.74   1.0  435    46
# 42      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    46
# 43           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    46
# 44            BoundedPareto-0-Ours  0.001   9.74   1.0  295    46
# 45    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    46
# 46         BoundedPareto-0-Dropout  0.001   9.74   1.0  121    46
# 47          BoundedMixGauss-0-Ours  0.001   9.74   1.0  428    46
# 48  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    46
# 49       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  173    46  ,                                                  perf  mean_perf  \
# 0   [0.3871, 0.9401, 0.957, 0.9707, 0.977, 0.9758,...     0.9839
# 1   [0.1729, 0.2253, 0.2734, 0.5202, 0.5955, 0.644...     0.8237
# 2   [0.1393, 0.1051, 0.1792, 0.3046, 0.2718, 0.343...     0.5790
# 3   [0.1027, 0.1769, 0.1522, 0.3617, 0.4875, 0.498...     0.7530
# 4   [0.131, 0.1954, 0.3817, 0.3985, 0.4873, 0.5517...     0.8128
# 5   [0.1393, 0.1051, 0.1792, 0.3046, 0.2718, 0.343...     0.5790
# 6   [0.1351, 0.1936, 0.2411, 0.2929, 0.4269, 0.475...     0.7181
# 7   [0.161, 0.1792, 0.2735, 0.5721, 0.5957, 0.6533...     0.8225
# 8   [0.1393, 0.1051, 0.1792, 0.3046, 0.2718, 0.343...     0.5790
# 9   [0.1664, 0.2324, 0.2124, 0.3519, 0.4696, 0.516...     0.7448
# 10  [0.6997, 0.9655, 0.9722, 0.9767, 0.9775, 0.978...     0.9850
# 11  [0.1031, 0.1699, 0.3924, 0.6025, 0.6528, 0.679...     0.8534
# 12  [0.0964, 0.1402, 0.2217, 0.311, 0.2797, 0.4095...     0.5766
# 13  [0.1, 0.2321, 0.2765, 0.4747, 0.5338, 0.5352, ...     0.7569
# 14  [0.1848, 0.2372, 0.3741, 0.5572, 0.6612, 0.617...     0.8276
# 15  [0.0964, 0.1402, 0.2217, 0.311, 0.2797, 0.4095...     0.5766
# 16  [0.1032, 0.2485, 0.3661, 0.3884, 0.4745, 0.519...     0.7514
# 17  [0.1331, 0.1652, 0.426, 0.5843, 0.6334, 0.6808...     0.8494
# 18  [0.0964, 0.1402, 0.2217, 0.311, 0.2797, 0.4095...     0.5766
# 19  [0.0996, 0.2241, 0.2298, 0.4288, 0.559, 0.5455...     0.7545
# 20  [0.5202, 0.9566, 0.9697, 0.9743, 0.9743, 0.979...     0.9847
# 21  [0.1694, 0.2569, 0.4153, 0.576, 0.601, 0.7003,...     0.8497
# 22  [0.181, 0.0929, 0.1377, 0.2674, 0.2882, 0.4056...     0.6336
# 23  [0.1617, 0.2847, 0.2845, 0.3223, 0.4289, 0.562...     0.8150
# 24  [0.1286, 0.3407, 0.4032, 0.4598, 0.588, 0.6214...     0.8446
# 25  [0.181, 0.0929, 0.1377, 0.2674, 0.2882, 0.4056...     0.6336
# 26  [0.1367, 0.1279, 0.3045, 0.4124, 0.3815, 0.507...     0.7605
# 27  [0.1348, 0.2519, 0.4305, 0.5566, 0.6053, 0.686...     0.8485
# 28  [0.181, 0.0929, 0.1377, 0.2674, 0.2882, 0.4056...     0.6336
# 29  [0.1435, 0.2484, 0.2903, 0.3305, 0.4245, 0.569...     0.8162
# 30  [0.6038, 0.9578, 0.9721, 0.9761, 0.9782, 0.980...     0.9852
# 31  [0.1992, 0.2364, 0.367, 0.4754, 0.561, 0.6083,...     0.8107
# 32  [0.1226, 0.181, 0.2555, 0.2628, 0.3579, 0.4325...     0.6088
# 33  [0.1286, 0.1571, 0.3134, 0.421, 0.5082, 0.5619...     0.7500
# 34  [0.1088, 0.1132, 0.3982, 0.4822, 0.574, 0.616,...     0.8050
# 35  [0.1226, 0.181, 0.2555, 0.2628, 0.3579, 0.4325...     0.6088
# 36  [0.157, 0.2154, 0.3323, 0.4469, 0.5249, 0.5381...     0.7327
# 37  [0.217, 0.2446, 0.3328, 0.4483, 0.5514, 0.5965...     0.8111
# 38  [0.1226, 0.181, 0.2555, 0.2628, 0.3579, 0.4325...     0.6088
# 39  [0.1376, 0.1569, 0.2857, 0.4262, 0.5357, 0.554...     0.7690
# 40  [0.3903, 0.9481, 0.9681, 0.9755, 0.9773, 0.98,...     0.9840
# 41  [0.1165, 0.1691, 0.3235, 0.4441, 0.5082, 0.631...     0.8307
# 42  [0.1187, 0.1758, 0.2072, 0.2694, 0.2619, 0.366...     0.5902
# 43  [0.1456, 0.1603, 0.2207, 0.2601, 0.4546, 0.515...     0.7263
# 44  [0.1535, 0.1899, 0.2613, 0.3905, 0.4848, 0.605...     0.8112
# 45  [0.1187, 0.1758, 0.2072, 0.2694, 0.2619, 0.366...     0.5902
# 46  [0.1476, 0.24, 0.3075, 0.4055, 0.4616, 0.5012,...     0.7563
# 47  [0.1247, 0.211, 0.3184, 0.4327, 0.4948, 0.616,...     0.8315
# 48  [0.1187, 0.1758, 0.2072, 0.2694, 0.2619, 0.366...     0.5902
# 49  [0.1494, 0.1749, 0.2229, 0.3275, 0.4539, 0.5, ...     0.7127
#
#                                  e      d     nm  norm   bs  seed
# 0                      PrivacyFree    NaN    NaN   NaN  128    42
# 1               ThreeLevels-0-Ours  0.001   9.74   1.0  435    42
# 2       ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    42
# 3            ThreeLevels-0-Dropout  0.001   9.74   1.0  175    42
# 4             BoundedPareto-0-Ours  0.001   9.74   1.0  293    42
# 5     BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    42
# 6          BoundedPareto-0-Dropout  0.001   9.74   1.0  120    42
# 7           BoundedMixGauss-0-Ours  0.001   9.74   1.0  411    42
# 8   BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    42
# 9        BoundedMixGauss-0-Dropout  0.001   9.74   1.0  166    42
# 10                     PrivacyFree    NaN    NaN   NaN  128    43
# 11              ThreeLevels-0-Ours  0.001   9.74   1.0  435    43
# 12      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    43
# 13           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    43
# 14            BoundedPareto-0-Ours  0.001   9.74   1.0  299    43
# 15    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    43
# 16         BoundedPareto-0-Dropout  0.001   9.74   1.0  123    43
# 17          BoundedMixGauss-0-Ours  0.001   9.74   1.0  471    43
# 18  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    43
# 19       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  185    43
# 20                     PrivacyFree    NaN    NaN   NaN  128    44
# 21              ThreeLevels-0-Ours  0.001   9.74   1.0  435    44
# 22      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    44
# 23           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    44
# 24            BoundedPareto-0-Ours  0.001   9.74   1.0  295    44
# 25    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    44
# 26         BoundedPareto-0-Dropout  0.001   9.74   1.0  123    44
# 27          BoundedMixGauss-0-Ours  0.001   9.74   1.0  442    44
# 28  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    44
# 29       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  175    44
# 30                     PrivacyFree    NaN    NaN   NaN  128    45
# 31              ThreeLevels-0-Ours  0.001   9.74   1.0  435    45
# 32      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    45
# 33           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    45
# 34            BoundedPareto-0-Ours  0.001   9.74   1.0  289    45
# 35    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    45
# 36         BoundedPareto-0-Dropout  0.001   9.74   1.0  118    45
# 37          BoundedMixGauss-0-Ours  0.001   9.74   1.0  447    45
# 38  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    45
# 39       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  180    45
# 40                     PrivacyFree    NaN    NaN   NaN  128    46
# 41              ThreeLevels-0-Ours  0.001   9.74   1.0  435    46
# 42      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    46
# 43           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    46
# 44            BoundedPareto-0-Ours  0.001   9.74   1.0  295    46
# 45    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    46
# 46         BoundedPareto-0-Dropout  0.001   9.74   1.0  121    46
# 47          BoundedMixGauss-0-Ours  0.001   9.74   1.0  428    46
# 48  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    46
# 49       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  173    46  ,                                                  perf  Performance  \
# 0   [0.2682, 0.6452, 0.8245, 0.9191, 0.9356, 0.947...       0.9767
# 1   [0.2589, 0.5504, 0.7406, 0.8339, 0.8477, 0.88,...       0.8990
# 2   [0.2589, 0.5805, 0.7467, 0.8433, 0.8508, 0.877...       0.9013
# 3   [0.2589, 0.5556, 0.7334, 0.8377, 0.8431, 0.877...       0.8974
# 4   [0.2589, 0.5728, 0.7274, 0.8373, 0.8396, 0.878...       0.9028
# 5   [0.2589, 0.5805, 0.7467, 0.8433, 0.8508, 0.877...       0.9013
# 6   [0.2589, 0.5845, 0.7275, 0.8429, 0.844, 0.8725...       0.8927
# 7   [0.2589, 0.5575, 0.7388, 0.8276, 0.8382, 0.873...       0.8974
# 8   [0.2589, 0.5805, 0.7467, 0.8433, 0.8508, 0.877...       0.9013
# 9   [0.2589, 0.5567, 0.745, 0.8302, 0.8385, 0.881,...       0.9002
# 10  [0.3932, 0.7229, 0.845, 0.8554, 0.9514, 0.9574...       0.9800
# 11  [0.3801, 0.6409, 0.7625, 0.7756, 0.8763, 0.885...       0.9084
# 12  [0.3801, 0.6571, 0.7569, 0.7806, 0.879, 0.9001...       0.8829
# 13  [0.3801, 0.6617, 0.7635, 0.7906, 0.8845, 0.903...       0.8973
# 14  [0.3801, 0.6595, 0.7638, 0.7891, 0.8857, 0.893...       0.8909
# 15  [0.3801, 0.6571, 0.7569, 0.7806, 0.879, 0.9001...       0.8829
# 16  [0.3801, 0.6714, 0.7731, 0.7878, 0.8788, 0.883...       0.8904
# 17  [0.3801, 0.6392, 0.7574, 0.7704, 0.8798, 0.889...       0.9072
# 18  [0.3801, 0.6571, 0.7569, 0.7806, 0.879, 0.9001...       0.8829
# 19  [0.3801, 0.6712, 0.7704, 0.7903, 0.8774, 0.883...       0.8923
# 20  [0.3617, 0.607, 0.6661, 0.7626, 0.7614, 0.9372...       0.9805
# 21  [0.4288, 0.5784, 0.6375, 0.7064, 0.7, 0.8691, ...       0.9030
# 22  [0.4288, 0.5703, 0.6333, 0.7017, 0.6987, 0.859...       0.8962
# 23  [0.4288, 0.582, 0.634, 0.7089, 0.709, 0.8626, ...       0.8930
# 24  [0.4288, 0.5823, 0.6338, 0.7031, 0.702, 0.8482...       0.8948
# 25  [0.4288, 0.5703, 0.6333, 0.7017, 0.6987, 0.859...       0.8962
# 26  [0.4288, 0.5852, 0.634, 0.7037, 0.702, 0.8665,...       0.8878
# 27  [0.4288, 0.5872, 0.635, 0.7029, 0.6974, 0.8581...       0.9002
# 28  [0.4288, 0.5703, 0.6333, 0.7017, 0.6987, 0.859...       0.8962
# 29  [0.4288, 0.5845, 0.6301, 0.701, 0.7004, 0.8573...       0.8910
# 30  [0.5231, 0.6514, 0.8225, 0.8581, 0.868, 0.9574...       0.9796
# 31  [0.4741, 0.6093, 0.7652, 0.806, 0.8136, 0.8701...       0.9001
# 32  [0.4741, 0.6076, 0.7417, 0.8059, 0.8237, 0.877...       0.9061
# 33  [0.4741, 0.6131, 0.7602, 0.8051, 0.8207, 0.883...       0.8946
# 34  [0.4741, 0.6101, 0.7486, 0.8115, 0.825, 0.8725...       0.8933
# 35  [0.4741, 0.6076, 0.7417, 0.8059, 0.8237, 0.877...       0.9061
# 36  [0.4741, 0.6103, 0.7502, 0.7968, 0.8153, 0.880...       0.9002
# 37  [0.4741, 0.6091, 0.7581, 0.8021, 0.8144, 0.87,...       0.9034
# 38  [0.4741, 0.6076, 0.7417, 0.8059, 0.8237, 0.877...       0.9061
# 39  [0.4741, 0.6147, 0.7667, 0.8021, 0.8211, 0.877...       0.8902
# 40  [0.3369, 0.6116, 0.9235, 0.9299, 0.9549, 0.960...       0.9787
# 41  [0.2999, 0.4893, 0.8099, 0.8434, 0.8675, 0.889...       0.8946
# 42  [0.2999, 0.5346, 0.7959, 0.8317, 0.8504, 0.879...       0.8868
# 43  [0.2999, 0.5143, 0.8031, 0.8515, 0.8818, 0.893...       0.9033
# 44  [0.2999, 0.5089, 0.8006, 0.8376, 0.8738, 0.897...       0.9031
# 45  [0.2999, 0.5346, 0.7959, 0.8317, 0.8504, 0.879...       0.8868
# 46  [0.2999, 0.518, 0.8155, 0.8463, 0.8637, 0.8665...       0.8940
# 47  [0.2999, 0.5075, 0.8121, 0.8368, 0.8681, 0.883...       0.8972
# 48  [0.2999, 0.5346, 0.7959, 0.8317, 0.8504, 0.879...       0.8868
# 49  [0.2999, 0.5127, 0.8168, 0.8556, 0.8769, 0.897...       0.9000
#
#                                  e      d     nm  norm   bs  seed
# 0                      PrivacyFree    NaN    NaN   NaN  128    42
# 1               ThreeLevels-0-Ours  0.001   9.74   1.0  435    42
# 2       ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    42
# 3            ThreeLevels-0-Dropout  0.001   9.74   1.0  175    42
# 4             BoundedPareto-0-Ours  0.001   9.74   1.0  293    42
# 5     BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    42
# 6          BoundedPareto-0-Dropout  0.001   9.74   1.0  120    42
# 7           BoundedMixGauss-0-Ours  0.001   9.74   1.0  411    42
# 8   BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    42
# 9        BoundedMixGauss-0-Dropout  0.001   9.74   1.0  166    42
# 10                     PrivacyFree    NaN    NaN   NaN  128    43
# 11              ThreeLevels-0-Ours  0.001   9.74   1.0  435    43
# 12      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    43
# 13           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    43
# 14            BoundedPareto-0-Ours  0.001   9.74   1.0  299    43
# 15    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    43
# 16         BoundedPareto-0-Dropout  0.001   9.74   1.0  123    43
# 17          BoundedMixGauss-0-Ours  0.001   9.74   1.0  471    43
# 18  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    43
# 19       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  185    43
# 20                     PrivacyFree    NaN    NaN   NaN  128    44
# 21              ThreeLevels-0-Ours  0.001   9.74   1.0  435    44
# 22      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    44
# 23           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    44
# 24            BoundedPareto-0-Ours  0.001   9.74   1.0  295    44
# 25    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    44
# 26         BoundedPareto-0-Dropout  0.001   9.74   1.0  123    44
# 27          BoundedMixGauss-0-Ours  0.001   9.74   1.0  442    44
# 28  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    44
# 29       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  175    44
# 30                     PrivacyFree    NaN    NaN   NaN  128    45
# 31              ThreeLevels-0-Ours  0.001   9.74   1.0  435    45
# 32      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    45
# 33           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    45
# 34            BoundedPareto-0-Ours  0.001   9.74   1.0  289    45
# 35    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    45
# 36         BoundedPareto-0-Dropout  0.001   9.74   1.0  118    45
# 37          BoundedMixGauss-0-Ours  0.001   9.74   1.0  447    45
# 38  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    45
# 39       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  180    45
# 40                     PrivacyFree    NaN    NaN   NaN  128    46
# 41              ThreeLevels-0-Ours  0.001   9.74   1.0  435    46
# 42      ThreeLevels-0-StrongForAll  0.001  13.75   1.0  128    46
# 43           ThreeLevels-0-Dropout  0.001   9.74   1.0  175    46
# 44            BoundedPareto-0-Ours  0.001   9.74   1.0  295    46
# 45    BoundedPareto-0-StrongForAll  0.001  13.75   1.0  128    46
# 46         BoundedPareto-0-Dropout  0.001   9.74   1.0  121    46
# 47          BoundedMixGauss-0-Ours  0.001   9.74   1.0  428    46
# 48  BoundedMixGauss-0-StrongForAll  0.001  13.75   1.0  128    46
# 49       BoundedMixGauss-0-Dropout  0.001   9.74   1.0  173    46  ]

# %%
import json
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid', {'axes.linewidth': 1, 'axes.edgecolor':'black'}) 

# vision
plt.close('all')
fig, axs = plt.subplots(3, 4, figsize=(12, 8), constrained_layout=True, dpi=500)

total_points = 1000
for i, ename in enumerate(enames):
    for j, params in enumerate(SETTINGS[ename]):
        target_epsilons = BoundedFunc(GENERATE_EPSILONS_FUNC[ename](total_points, params))
        sns.histplot(x=target_epsilons, stat="count", ax=axs[i][0], label=f'params{j}')
    
    axs[i][0].set_title(f'{ename}', **title_font)
    axs[i][0].set_ylabel('Density', **label_font)
    axs[i][0].set_xlabel('Epsilon', **label_font)
    axs[i][0].tick_params(labelsize=8)
    
    # ===============
    if ename != 'ThreeLevels':
        # Add a child inset Axes to this existing Axes
        axin = inset_axes(axs[i][0], width='50%', height='40%', loc='lower center', 
                           bbox_to_anchor=(0.1,0.3,1,1), 
                           bbox_transform=axs[i][0].transAxes)
        sub_temp = sns.histplot(x=target_epsilons[target_epsilons >= 1.5], ax=axin, stat="count")
        #color=sns.color_palette()[4]
        
        # ax4in.set_ylim(0, 30)
        axin.tick_params(labelsize=8)
        mark_inset(axs[i][0], axin, loc1=1, loc2=3, fc="none", ec='k', lw=1)
        axin.set_ylabel(None, **label_font)
    # ===============

for i, e in enumerate(enames):
    for k, ds in enumerate(datasets):
        results = all_results[k]
        nm = [nm for nm in results["nm"].unique() if not (np.isnan(nm))][0]
        d = [d for d in results["d"].unique() if not (np.isnan(d))][0]
        print(d)
        
        for j, method in enumerate(methods):
            if method == "PrivacyFree":
                cdf = results.loc[results["e"] == method]
            else:
                cdf = results.loc[results["e"].str.contains(e, na=False)].loc[results["e"].str.contains(method, na=False)].loc[results["d"] == d]
                
            
            perf_str = np.array(cdf["perf"].tolist())
            data_arr = np.array([json.loads(_str) for _str in perf_str])
            data_mean = data_arr.mean(axis=0)
            data_std = data_arr.std(axis=0)
            print("data_arr shape:", data_arr.shape)
                        
            print(i," ",j ," ",k," ",ds," ",j," ",method)
            print(type(data_arr), data_arr.shape)
            print(type(data_mean))
            
            label = method if method != "StrongForAll" else "Minimum"
            sns.lineplot(data=data_mean, label=label, linestyle=linestyles[::-1][j][1], ax=axs[i][k+1])

        axs[i][k+1].set_title(f'{ds}', **title_font)
        axs[i][k+1].legend(loc='upper right', prop=legend_font)
        axs[i][k+1].set_ylabel('Test Acc', **label_font)
        axs[i][k+1].set_xlabel('Round', **label_font)
        
        axs[i][k+1].set_ylim(0., 1.)
        axs[i][k+1].set_xticks(range(15))
        axs[i][k+1].tick_params(labelsize=8)
        axs[i][k+1].legend(loc='lower right', prop=legend_font)

plt.savefig("fed_6plots.pdf", dpi=500, bbox_inches='tight')
plt.show()
# Out:
# 0.001
# data_arr shape: (5, 15)
# 0   0   0   FedAvg   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   1   0   FedAvg   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   2   0   FedAvg   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   3   0   FedAvg   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 0   0   1   Ditto-Global   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   1   1   Ditto-Global   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   2   1   Ditto-Global   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   3   1   Ditto-Global   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 0   0   2   Ditto-Personal   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   1   2   Ditto-Personal   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   2   2   Ditto-Personal   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 0   3   2   Ditto-Personal   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 1   0   0   FedAvg   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   1   0   FedAvg   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   2   0   FedAvg   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   3   0   FedAvg   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 1   0   1   Ditto-Global   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   1   1   Ditto-Global   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   2   1   Ditto-Global   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   3   1   Ditto-Global   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 1   0   2   Ditto-Personal   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   1   2   Ditto-Personal   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   2   2   Ditto-Personal   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 1   3   2   Ditto-Personal   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 2   0   0   FedAvg   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   1   0   FedAvg   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   2   0   FedAvg   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   3   0   FedAvg   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 2   0   1   Ditto-Global   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   1   1   Ditto-Global   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   2   1   Ditto-Global   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   3   1   Ditto-Global   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# 0.001
# data_arr shape: (5, 15)
# 2   0   2   Ditto-Personal   0   PrivacyFree
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   1   2   Ditto-Personal   1   Ours
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   2   2   Ditto-Personal   2   Dropout
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>
# data_arr shape: (5, 15)
# 2   3   2   Ditto-Personal   3   StrongForAll
# <class 'numpy.ndarray'> (5, 15)
# <class 'numpy.ndarray'>

# %%
results_heart = {
    "norm_sq_budgets": [5, 20, 100],
    "max_grad_norm": 1.0,
    "results": pd.read_csv("./original_submission_results/fed_heart_disease/results_filter.csv")
}
results_mnist = {
    "norm_sq_budgets": [100, 500, 2500],
    "max_grad_norm": 5.0,
    "results": pd.read_csv("./original_submission_results/fed_mnist_iid/results_filter.csv")
}

sec1 = np.array(results_heart["results"]["seconds"].tolist()).mean()
sec2 = np.array(results_mnist["results"]["seconds"].tolist()).mean()
sec1, sec2
# Out:
# (0.01282251655629139, 7.101640397350994)

# %%
def draw_spot(ax, x0, y0, z0):
    ax.scatter(x0, y0, s=30, color='r')
    ax.plot([x0, x0], [y0, 0], 'm--', lw=1)
    ax.plot([0, x0], [y0, y0], 'm--', lw=1)
    show_spot = '(' + str(x0) + ',' + str(y0) + ', ε=' + str(z0) + ')'
    ax.annotate(show_spot, xy=(x0, y0), xytext=(x0, y0))
    
fig, axs = plt.subplots(1, 2, figsize=(7, 3), constrained_layout=True, dpi=500)

sns.lineplot(data=np.array(results_heart["results"]["num_active_points"].tolist()), ax=axs[0])
running_eps = results_heart["results"]["e"].tolist()
x = int(np.floor(results_heart["norm_sq_budgets"][0]/results_heart["max_grad_norm"]**2))
y = results_heart["results"]["num_active_points"][x]
z = round(list(json.loads(running_eps[x]).values())[0], 1)
draw_spot(axs[0], x, y, z)

x = int(np.floor(results_heart["norm_sq_budgets"][1]/results_heart["max_grad_norm"]**2))
y = results_heart["results"]["num_active_points"][x]
z = round(list(json.loads(running_eps[x]).values())[1], 1)
draw_spot(axs[0], x, y, z)

x = int(np.floor(results_heart["norm_sq_budgets"][2]/results_heart["max_grad_norm"]**2))
y = results_heart["results"]["num_active_points"][x]
z = round(list(json.loads(running_eps[x]).values())[2], 1)
draw_spot(axs[0], x, y, z)

axs[0].set_xlabel("Step", **label_font)
axs[0].set_ylabel("Number of active points", **label_font)
axs[0].set_ylim(0, 540)
axs[0].set_title("Fed-Heart-Disease (pooled)", **title_font)

sns.lineplot(data=np.array(results_mnist["results"]["num_active_points"].tolist()), ax=axs[1])
running_eps = results_mnist["results"]["e"].tolist()
x = int(np.floor(results_mnist["norm_sq_budgets"][0]/results_mnist["max_grad_norm"]**2))
y = results_mnist["results"]["num_active_points"][x]
z = round(list(json.loads(running_eps[x]).values())[0], 1)
draw_spot(axs[1], x, y, z)

x = int(np.floor(results_mnist["norm_sq_budgets"][1]/results_mnist["max_grad_norm"]**2))
y = results_mnist["results"]["num_active_points"][x]
z = round(list(json.loads(running_eps[x]).values())[1], 1)
draw_spot(axs[1], x, y, z)

x = int(np.floor(results_mnist["norm_sq_budgets"][2]/results_mnist["max_grad_norm"]**2))
y = results_mnist["results"]["num_active_points"][x]
z = round(list(json.loads(running_eps[x]).values())[2], 1)
draw_spot(axs[1], x, y, z)

axs[1].set_xlabel("Step", **label_font)
axs[1].set_ylim(0, 65000)
axs[1].set_title("MNIST (pooled)", **title_font)

plt.savefig('filter_active_points.pdf', bbox_inches='tight')
print(f"second: heart disease = {sec1:.4f}, mnist = {sec2:.4f}")
# Out:
# second: heart disease = 0.0128, mnist = 7.1016
